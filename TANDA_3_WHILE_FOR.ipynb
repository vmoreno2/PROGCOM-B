# %%
##11.
##(while)
print("Escribe una frase de la canción:")
frase = input()
while True:
 if frase == "¿Quién es?":
  print("Soy yo")
 elif frase == "¿Qué vienes a buscar?":
  print("A ti")
 elif frase == "Ya es tarde":
  print("¿Por qué?")
 elif frase == "Porque ahora soy yo":
  print("La que quiere estar sin ti")
 else:
  print("Frase no encontrada")
break
##(for)
print("Escribe una frase de la canción:")
  frase = input()
 for i in range(1):
  if frase == "¿Quién es?":
   print("Soy yo")
 elif frase == "¿Qué vienes a buscar?":
   print("A ti")
 elif frase == "Ya es tarde":
   print("¿Por qué?")
elif frase == "Porque ahora soy yo":
   print("La que quiere estar sin ti")
else:
print("Frase no encontrada")

##12.
##(while)
s = "Salacadula Chalchicomula"
b = "Bibidi Babidi Bu."
e = [
    f"{s}\n{b}\nSiete palabras de magia que son:\n{b}",
    f"{s}\n{b}\nYo hago milagros con esta canción:\n{b}",
    f"Tu Salacadula di\ny Chalchicomula mu,\npero para lograr un gran amor\ndi {b}",
    f"{s}\n{b}\nTodo se logra con solo decir:\nBibidi Babidi,\nBibidi Babidi,\n{b}",]
i = 0
while i < len(e):
    print(e[i] + "\n")
    i += 1
##(for)
s = "Salacadula Chalchicomula"
b = "Bibidi Babidi Bu."
for e in estrofas:
        print(f"{e}\n")


i([
    f"{s}\n{b}\nSiete palabras de magia que son:\n{b}",
    f"{s}\n{b}\nYo hago milagros con esta canción:\n{b}",
    f"Tu Salacadula di\ny Chalchicomula mu,\npero para lograr un gran amor\ndi {b}",
    f"{s}\n{b}\nTodo se logra con solo decir:\nBibidi Babidi,\nBibidi Babidi,\n{b}",
])

##13.
##(while)
login = input("Ingrese su login: ")
password = input("Ingrese su password: ")

while len(password) < 10:
print("El password debe tener mínimo 10 caracteres")
password = input("Ingrese nuevamente el password: ")

while not password[0].isupper():
print("El primer carácter debe ser mayúscula")
password = input("Ingrese nuevamente el password: ")

especial = False
numero = False

i = 0

while i < len(password):
if password[i] in "$/@%&":
especial = True

if password[i].isdigit():
numero = True

i = i + 1

while especial == False or numero == False:
print("El password debe tener un carácter especial y un número")
password = input("Ingrese nuevamente el password: ")

especial = False
numero = False
i = 0

while i < len(password):
if password[i] in "$/@%&":
especial = True

if password[i].isdigit():
numero = True

i = i + 1

print("Login y password creados correctamente")
##(for)
login = input("Ingrese su login: ")
password = input("Ingrese su password: ")

mayuscula = password[0].isupper()
numero = False
especial = False

for caracter in password:
    if caracter.isdigit():
        numero = True

    if caracter in "$/@%&":
        especial = True

if len(password) >= 10 and mayuscula and numero and especial:
    print("Login y password creados correctamente")
else:
    print("El password no cumple las condiciones")

##14.
##(while)
print("----- TIENDA -----")

print("1. Arroz $4000")
print("2. Leche $3500")
print("3. Pan $2500")
print("4. Huevos $18000")
print("5. Café $12000")
print("6. Azúcar $4500")
print("7. Aceite $9000")
print("8. Galletas $3000")
print("9. Gaseosa $4000")
print("10. Chocolate $5000")
print("0. Terminar compra")

total = 0

codigo = int(input("Ingrese el código del producto: "))

while codigo != 0:

if codigo == 1:
precio = 4000
elif codigo == 2:
precio = 3500
elif codigo == 3:
precio = 2500
elif codigo == 4:
precio = 18000
elif codigo == 5:
precio = 12000
elif codigo == 6:
precio = 4500
elif codigo == 7:
precio = 9000
elif codigo == 8:
precio = 3000
elif codigo == 9:
precio = 4000
elif codigo == 10:
precio = 5000
else:
print("Código incorrecto")
precio = 0

if precio > 0:
cantidad = int(input("Ingrese la cantidad: "))
total = total + precio * cantidad

codigo = int(input("Ingrese otro código (0 para terminar): "))

iva = total * 0.19
total_pagar = total + iva

print("Subtotal:", total)
print("IVA:", iva)
print("Total a pagar:", total_pagar)

recibido = float(input("Ingrese el dinero recibido: "))

while recibido < total_pagar:
print("Dinero insuficiente")
recibido = float(input("Ingrese nuevamente el dinero: "))

cambio = recibido - total_pagar

print("Valor recibido:", recibido)
print("Valor a entregar:", cambio)
##(for)


##15.
##(while)
import calendar
from datetime import date

meses_es = [
    "", "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
]


festivos = {
    date(2016, 1, 1): "Año Nuevo",
    date(2016, 1, 11): "Reyes Magos",
    date(2016, 3, 21): "Día de San José",
    date(2016, 3, 24): "Jueves Santo",
    date(2016, 3, 25): "Viernes Santo",
    date(2016, 5, 1): "Día del Trabajo",
    date(2016, 5, 9): "Ascensión del Señor",
    date(2016, 5, 30): "Corpus Christi",
    date(2016, 6, 6): "Sagrado Corazón",
    date(2016, 7, 4): "San Pedro y San Pablo",
    date(2016, 7, 20): "Independencia Nacional",
    date(2016, 8, 7): "Batalla de Boyacá",
    date(2016, 8, 15): "La Asunción de la Virgen",
    date(2016, 10, 17): "Día de la Raza",
    date(2016, 11, 7): "Todos los Santos",
    date(2016, 11, 14): "Independencia de Cartagena",
    date(2016, 12, 8): "Inmaculada Concepción",
    date(2016, 12, 25): "Navidad",
}

mes = 1
while mes <= 12:
    num_dias = calendar.monthrange(2016, mes)[1]

    print(f"\n================ {meses_es[mes].upper()} 2016 ================")
    print(" Lu  Ma  Mi  Ju  Vi  Sá  Do")
    diini = date(2016, mes, 1).weekday()
    espacios = 0
    while espacios < diini:
        print("    ", end="")
        espacios += 1
    dia = 1
    columna = diini

    while dia <= num_dias:
        fecha_actual = date(2016, mes, dia)
        if fecha_actual in festivos:
            print(f"{dia:2d}*", end=" ")
        else:
            print(f"{dia:2d} ", end=" ")

        columna += 1
        if columna % 7 == 0:
            print()

        dia += 1

    print()
    mes += 1

print("\n--- DETALLE DE DÍAS FESTIVOS 2016 ---")
lista_festivos = list(festivos.keys())
i = 0
while i < len(lista_festivos):
    f = lista_festivos[i]
    print(f"• {f.strftime('%d/%m/%Y')}: {festivos[f]}")
    i += 1
##(for)
import calendar
from datetime import date

meses_es = [
    "", "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
]

festivos = {
    date(2016, 1, 1): "Año Nuevo",
    date(2016, 1, 11): "Reyes Magos",
    date(2016, 3, 21): "Día de San José",
    date(2016, 3, 24): "Jueves Santo",
    date(2016, 3, 25): "Viernes Santo",
    date(2016, 5, 1): "Día del Trabajo",
    date(2016, 5, 9): "Ascensión del Señor",
    date(2016, 5, 30): "Corpus Christi",
    date(2016, 6, 6): "Sagrado Corazón",
    date(2016, 7, 4): "San Pedro y San Pablo",
    date(2016, 7, 20): "Independencia Nacional",
    date(2016, 8, 7): "Batalla de Boyacá",
    date(2016, 8, 15): "La Asunción de la Virgen",
    date(2016, 10, 17): "Día de la Raza",
    date(2016, 11, 7): "Todos los Santos",
    date(2016, 11, 14): "Independencia de Cartagena",
    date(2016, 12, 8): "Inmaculada Concepción",
    date(2016, 12, 25): "Navidad",
}

for mes in range(1, 13):
    num_dias = calendar.monthrange(2016, mes)[1]

    print(f"\n================ {meses_es[mes].upper()} 2016 ================")
    print(" Lu  Ma  Mi  Ju  Vi  Sá  Do")

    dia_inicio = date(2016, mes, 1).weekday()
    for _ in range(dia_inicio):
        print("    ", end="")

    columna = dia_inicio

    for dia in range(1, num_dias + 1):
        fecha_actual = date(2016, mes, dia)


        if fecha_actual in festivos:
            print(f"{dia:2d}*", end=" ")
        else:
            print(f"{dia:2d} ", end=" ")

        columna += 1
        if columna % 7 == 0:
            print()

    print()


print("\n--- DETALLE DE DÍAS FESTIVOS 2016 ---")
for fecha, nombre in festivos.items():
    print(f"• {fecha.strftime('%d/%m/%Y')}: {nombre}")
